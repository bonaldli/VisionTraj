# %%
import networkx as nx
import pickle
import geonetworkx as gnx
import matplotlib.pyplot as plt
import json
import osmnx as ox
import pickle

# %% [markdown]
# alg_mapmatching->alg_sim_graph->cluster(run.py)->alg_cluster

# %%
map_file = "../dataset/"

# %%
# import osmnx as ox

# # 获取地点的街道网络
# graph = ox.graph_from_bbox(22.695,
#                            22.585,
#                            114.065,
#                            113.96,
#                            network_type="drive",
#                            simplify=False)

# # 保存为OSM文件
# ox.save_graph_xml(graph, filepath="./map.osm.xml")

# %%
graph = pickle.load(open(map_file + 'longhua_2w.pkl', 'rb'))
len(graph.nodes())
# Out:
# 28295

# %%
# import pickle

# pickle.dump(graph, open(map_file + 'longhua_2w.pkl', 'wb'))

# %%
ans = ox.simplify_graph(graph)

# %%
G2 = ox.consolidate_intersections(ans, tolerance=0.00025)
len(G2.nodes())
# Out:
# /opt/miniconda3/envs/torch191/lib/python3.9/site-packages/osmnx/simplification.py:426: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# /opt/miniconda3/envs/torch191/lib/python3.9/site-packages/osmnx/simplification.py:474: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
# 1839

# %%
ox.plot_graph(G2)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %%
pickle.dump(G2, open(map_file + 'longhua_1.8k.pkl', 'wb'))
